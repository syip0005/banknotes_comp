# %%
import pandas as pd
import numpy as np
import torch
from torch.utils.data import DataLoader, Dataset
from torch import nn, optim
from torchvision import datasets
from pathlib import Path
import matplotlib.pyplot as plt
plt.rcParams["savefig.bbox"] = 'tight'
from torchvision.transforms import v2
from torchvision.io import read_image
torch.manual_seed(1) # seed
from helpers import plot, random_combination
import os
import shutil
import time
from tempfile import TemporaryDirectory
from PIL import Image
from os import listdir
from os.path import isfile, join

from torchvision.models import alexnet, AlexNet_Weights, convnext_tiny, ConvNeXt_Tiny_Weights, swin_v2_t, Swin_V2_T_Weights, efficientnet_v2_s, EfficientNet_V2_S_Weights, mobilenet_v3_large
from torchvision.models import MobileNet_V3_Large_Weights

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
weights = EfficientNet_V2_S_Weights.DEFAULT
model = efficientnet_v2_s(weights = None) # weights = weights
standard_preprocess = weights.transforms()

# %%
data_transforms = {
                    'train': v2.Compose([
                            v2.RandomApply([v2.RandAugment()], p = .5),
                            v2.RandomResizedCrop(size=(224, 224), antialias=True),
                            v2.RandomHorizontalFlip(p=0.5),
                            v2.ToTensor(),
                            v2.ToDtype(torch.float32, scale=True),
                            v2.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])]),
                   'val': standard_preprocess}
data_dir = './Dataset_Categorised_with_Supplement/'

image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x),
                                          data_transforms[x])
                  for x in ['train', 'val']}

dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=32,
                                             shuffle=True, num_workers=4)
              for x in ['train', 'val']}

dataset_sizes = {x: len(image_datasets[x]) for x in ['train', 'val']}

class_names = image_datasets['train'].classes
# Out:
# c:\Users\zoga\anaconda3\envs\kaggle_comp\Lib\site-packages\torchvision\transforms\v2\_deprecated.py:43: UserWarning: The transform `ToTensor()` is deprecated and will be removed in a future release. Instead, please use `v2.Compose([v2.ToImage(), v2.ToDtype(torch.float32, scale=True)])`.
#   warnings.warn(

# %%
def visualize_model(model, num_images=6):
    was_training = model.training
    model.eval()
    images_so_far = 0
    fig = plt.figure()

    with torch.no_grad():
        for i, (inputs, labels) in enumerate(dataloaders['val']):
            inputs = inputs.to(device)
            labels = labels.to(device)

            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)

            for j in range(inputs.size()[0]):
                images_so_far += 1
                ax = plt.subplot(num_images//2, 2, images_so_far)
                ax.axis('off')
                ax.set_title(f'predicted: {class_names[preds[j]]}')
                imshow(inputs.cpu().data[j])

                if images_so_far == num_images:
                    model.train(mode=was_training)
                    return
        model.train(mode=was_training)

def visualize_model_predictions(model,img_path):
    was_training = model.training
    model.eval()

    img = Image.open(img_path)
    img = standard_preprocess(img)
    img = img.unsqueeze(0)
    img = img.to(device)

    with torch.no_grad():
        outputs = model(img)
        _, preds = torch.max(outputs, 1)

        ax = plt.subplot(2,2,1)
        ax.axis('off')
        ax.set_title(f'Predicted: {class_names[preds[0]]}')
        imshow(img.cpu().data[0])

        model.train(mode=was_training)

def predict(model,img_path):
    was_training = model.training
    model.eval()

    img = Image.open(img_path)
    img = data_transforms['val'](img)
    img = img.unsqueeze(0)
    img = img.to(device)

    with torch.no_grad():
        outputs = model(img)
        _, preds = torch.max(outputs, 1)

        return preds
    
def predict_proba(model,img_path):
    was_training = model.training
    model.eval()

    img = Image.open(img_path)
    img = data_transforms['val'](img)
    img = img.unsqueeze(0)
    img = img.to(device)

    with torch.no_grad():
        outputs = model(img)
        preds = outputs

        return preds

# %%
df_train_labels = pd.read_csv('./Dataset/train_labels.csv')

# %%
def train_model(model, criterion, optimizer, scheduler, num_epochs=5):
    since = time.time()

    epoch_data = {'train_acc': [], 'train_loss': [], 'val_acc': [], 'val_loss': []}

    # Create a temporary directory to save training checkpoints
    with TemporaryDirectory() as tempdir:
        best_model_params_path = os.path.join(tempdir, 'best_model_params.pt')

        torch.save(model.state_dict(), best_model_params_path)
        best_acc = 0.0

        for epoch in range(num_epochs):
            print(f'Epoch {epoch}/{num_epochs - 1}')
            print('-' * 10)

            # Each epoch has a training and validation phase
            for phase in ['train', 'val']:
                if phase == 'train':
                    model.train()  # Set model to training mode
                else:
                    model.eval()   # Set model to evaluate mode

                running_loss = 0.0
                running_corrects = 0

                # Iterate over data.
                for inputs, labels in dataloaders[phase]:
                    inputs = inputs.to(device)
                    labels = labels.to(device)

                    # zero the parameter gradients
                    optimizer.zero_grad()

                    # forward
                    # track history if only in train
                    with torch.set_grad_enabled(phase == 'train'):
                        outputs = model(inputs)
                        _, preds = torch.max(outputs, 1)
                        loss = criterion(outputs, labels)

                        # backward + optimize only if in training phase
                        if phase == 'train':
                            loss.backward()
                            optimizer.step()

                    # statistics
                    running_loss += loss.item() * inputs.size(0)
                    running_corrects += torch.sum(preds == labels.data)
                if phase == 'train':
                    scheduler.step()

                epoch_loss = running_loss / dataset_sizes[phase]
                epoch_acc = running_corrects.double() / dataset_sizes[phase]

                if phase == 'train':
                    epoch_data['train_acc'].append(epoch_acc)
                    epoch_data['train_loss'].append(epoch_loss)
                elif phase == 'val':
                    epoch_data['val_acc'].append(epoch_acc)
                    epoch_data['val_loss'].append(epoch_loss)

                print(f'{phase} Loss: {epoch_loss:.4f} Acc: {epoch_acc:.4f}')

                # deep copy the model
                if phase == 'val' and epoch_acc > best_acc:
                    best_acc = epoch_acc
                    torch.save(model.state_dict(), best_model_params_path)

            print()

        time_elapsed = time.time() - since
        print(f'Training complete in {time_elapsed // 60:.0f}m {time_elapsed % 60:.0f}s')
        print(f'Best val Acc: {best_acc:4f}')

        # load best model weights
        model.load_state_dict(torch.load(best_model_params_path))
        
    return model, epoch_data, best_acc

# %%
all_test_files_jpeg = listdir('./Dataset/test/')
all_test_files = ['./Dataset/test/' + i for i in all_test_files_jpeg]

model_architectures = [alexnet, convnext_tiny, swin_v2_t, efficientnet_v2_s, mobilenet_v3_large]
model_names = ['alex', 'convnext', 'swin', 'efficientnet', 'mobilenet']

for model_name, model_a in zip(model_names, model_architectures):

    print(f'\n{model_name}')

    model_temp = model_a(weights = None)

    model_classifier_temp = nn.Sequential(model_temp, nn.Linear(1000, 4))
    model_classifier_temp.to(device)

    optimizer_ft = optim.Adam(model_classifier_temp.parameters(), lr=1e-4)
    exp_lr_scheduler = optim.lr_scheduler.StepLR(optimizer_ft, step_size=20, gamma=0.9)
    criterion = nn.CrossEntropyLoss()

    model_ft_temp, model_ft_epoch_data_temp, model_best_acc_temp = train_model(model_classifier_temp, criterion, optimizer_ft, exp_lr_scheduler,
                       num_epochs=200)
    
    print('performing predictions...')

    all_test_pred = np.empty((0,4))
    for file_str in all_test_files:
        all_test_pred = np.vstack([all_test_pred, predict_proba(model_ft_temp, file_str).cpu().numpy()])

    # saving...
    
    save_model_loc_temp = f'./models/{model_name}_{model_best_acc_temp:.2f}.pt'
    save_results_loc_temp = f'./predictions/{model_name}_{model_best_acc_temp:.2f}_results.npy'

    print(f'saving model to {save_model_loc_temp}...')
    torch.save(model_ft_temp.state_dict(), save_model_loc_temp)

    print(f'saving results to {save_results_loc_temp}...')
    with open(save_results_loc_temp, 'wb') as f:
        np.save(save_results_loc_temp, all_test_pred)
# Out:
# alex
# Epoch 0/199
# ----------
# train Loss: 1.3415 Acc: 0.3086
# val Loss: 1.4144 Acc: 0.3827
#
# Epoch 1/199
# ----------
# train Loss: 1.3175 Acc: 0.3593
# val Loss: 1.3628 Acc: 0.3704
#
# Epoch 2/199
# ----------
# train Loss: 1.2658 Acc: 0.4193
# val Loss: 1.2057 Acc: 0.4938
#
# Epoch 3/199
# ----------
# train Loss: 1.1947 Acc: 0.5012
# val Loss: 1.1238 Acc: 0.5309
#
# Epoch 4/199
# ----------
# train Loss: 1.1456 Acc: 0.5360
# val Loss: 1.1040 Acc: 0.6173
#
# Epoch 5/199
# ----------
# train Loss: 1.1153 Acc: 0.5490
# val Loss: 1.0957 Acc: 0.5679
#
# Epoch 6/199
# ----------
# train Loss: 1.0848 Acc: 0.5608
# val Loss: 0.9814 Acc: 0.5556
#
# Epoch 7/199
# ----------
# train Loss: 1.0665 Acc: 0.5749
# val Loss: 0.9855 Acc: 0.6543
#
# Epoch 8/199
# ----------
# train Loss: 1.0346 Acc: 0.5884
# val Loss: 0.9847 Acc: 0.6543
#
# Epoch 9/199
# ----------
# train Loss: 0.9961 Acc: 0.6182
# val Loss: 0.9020 Acc: 0.6790
#
# Epoch 10/199
# ----------
# train Loss: 0.9725 Acc: 0.6230
# val Loss: 0.9704 Acc: 0.6296
#
# Epoch 11/199
# ----------
# train Loss: 0.9693 Acc: 0.6213
# val Loss: 0.7259 Acc: 0.7284
#
# Epoch 12/199
# ----------
# train Loss: 0.9398 Acc: 0.6335
# val Loss: 0.8592 Acc: 0.6420
#
# Epoch 13/199
# ----------
# train Loss: 0.8997 Acc: 0.6547
# val Loss: 0.6232 Acc: 0.8395
#
# Epoch 14/199
# ----------
# train Loss: 0.8791 Acc: 0.6535
# val Loss: 0.5602 Acc: 0.8272
#
# Epoch 15/199
# ----------
# train Loss: 0.8618 Acc: 0.6724
# val Loss: 0.5662 Acc: 0.8395
#
# Epoch 16/199
# ----------
# train Loss: 0.8613 Acc: 0.6707
# val Loss: 0.6249 Acc: 0.8148
#
# Epoch 17/199
# ----------
# train Loss: 0.8435 Acc: 0.6753
# val Loss: 0.5232 Acc: 0.9136
#
# Epoch 18/199
# ----------
# train Loss: 0.8317 Acc: 0.6811
# val Loss: 0.5452 Acc: 0.8519
#
# Epoch 19/199
# ----------
# train Loss: 0.7915 Acc: 0.6952
# val Loss: 0.4662 Acc: 0.8395
#
# Epoch 20/199
# ----------
# train Loss: 0.7796 Acc: 0.7075
# val Loss: 0.4746 Acc: 0.8642
#
# Epoch 21/199
# ----------
# train Loss: 0.7745 Acc: 0.7039
# val Loss: 0.4702 Acc: 0.8519
#
# Epoch 22/199
# ----------
# train Loss: 0.7794 Acc: 0.7024
# val Loss: 0.5480 Acc: 0.8765
#
# Epoch 23/199
# ----------
# train Loss: 0.7719 Acc: 0.7094
# val Loss: 0.4756 Acc: 0.8765
#
# Epoch 24/199
# ----------
# train Loss: 0.7517 Acc: 0.7171
# val Loss: 0.4053 Acc: 0.8642
#
# Epoch 25/199
# ----------
# train Loss: 0.7611 Acc: 0.7053
# val Loss: 0.6075 Acc: 0.7654
#
# Epoch 26/199
# ----------
# train Loss: 0.7427 Acc: 0.7195
# val Loss: 0.4723 Acc: 0.9259
#
# Epoch 27/199
# ----------
# train Loss: 0.7168 Acc: 0.7274
# val Loss: 0.3584 Acc: 0.9383
#
# Epoch 28/199
# ----------
# train Loss: 0.7171 Acc: 0.7260
# val Loss: 0.4916 Acc: 0.8395
#
# Epoch 29/199
# ----------
# train Loss: 0.7014 Acc: 0.7327
# val Loss: 0.4425 Acc: 0.8519
#
# Epoch 30/199
# ----------
# train Loss: 0.7072 Acc: 0.7322
# val Loss: 0.3989 Acc: 0.8765
#
# Epoch 31/199
# ----------
# train Loss: 0.6920 Acc: 0.7428
# val Loss: 0.4364 Acc: 0.8642
#
# Epoch 32/199
# ----------
# train Loss: 0.6988 Acc: 0.7274
# val Loss: 0.4782 Acc: 0.8765
#
# Epoch 33/199
# ----------
# train Loss: 0.6854 Acc: 0.7385
# val Loss: 0.4092 Acc: 0.9259
#
# Epoch 34/199
# ----------
# train Loss: 0.6743 Acc: 0.7514
# val Loss: 0.4052 Acc: 0.8519
#
# Epoch 35/199
# ----------
# train Loss: 0.6685 Acc: 0.7435
# val Loss: 0.4434 Acc: 0.8519
#
# Epoch 36/199
# ----------
# train Loss: 0.6643 Acc: 0.7495
# val Loss: 0.3855 Acc: 0.9136
#
# Epoch 37/199
# ----------
# train Loss: 0.6526 Acc: 0.7514
# val Loss: 0.4862 Acc: 0.8148
#
# Epoch 38/199
# ----------
# train Loss: 0.6543 Acc: 0.7538
# val Loss: 0.3839 Acc: 0.8765
#
# Epoch 39/199
# ----------
# train Loss: 0.6266 Acc: 0.7685
# val Loss: 0.3972 Acc: 0.8519
#
# Epoch 40/199
# ----------
# train Loss: 0.6453 Acc: 0.7553
# val Loss: 0.3752 Acc: 0.8519
#
# Epoch 41/199
# ----------
# train Loss: 0.6042 Acc: 0.7716
# val Loss: 0.3313 Acc: 0.8765
#
# Epoch 42/199
#
# Epoch 193/199
# ----------
# train Loss: 0.5286 Acc: 0.8028
# val Loss: 0.2151 Acc: 0.9259
#
# Epoch 194/199
# ----------
# train Loss: 0.5527 Acc: 0.7966
# val Loss: 0.2176 Acc: 0.9506
#
# Epoch 195/199
# ----------
# train Loss: 0.5351 Acc: 0.8033
# val Loss: 0.2365 Acc: 0.9506
#
# Epoch 196/199
# ----------
# train Loss: 0.5390 Acc: 0.8026
# val Loss: 0.2670 Acc: 0.9012
#
# Epoch 197/199
# ----------
# train Loss: 0.5394 Acc: 0.7995
# val Loss: 0.2015 Acc: 0.9753
#
# Epoch 198/199
# ----------
# train Loss: 0.5322 Acc: 0.8033
# val Loss: 0.2576 Acc: 0.9383
#
# Epoch 199/199
# ----------
# train Loss: 0.5513 Acc: 0.7947
# val Loss: 0.2447 Acc: 0.9136
#
# Training complete in 180m 10s
# Best val Acc: 0.975309
# performing predictions...
# saving model to ./models/convnext_0.98.pt...
# saving results to ./predictions/convnext_0.98_results.npy...
#
# swin
# Epoch 0/199
# ----------
# train Loss: 1.3418 Acc: 0.3701
# val Loss: 1.2988 Acc: 0.4691
#
# Epoch 1/199
# ----------
# train Loss: 1.2051 Acc: 0.4926
# val Loss: 1.2426 Acc: 0.5062
#
# Epoch 2/199
# ----------
# train Loss: 1.1406 Acc: 0.5348
# val Loss: 1.1585 Acc: 0.4815
#
# Epoch 3/199
# ----------
# train Loss: 1.1113 Acc: 0.5545
# val Loss: 1.2304 Acc: 0.4938
#
# Epoch 4/199
# ----------
# train Loss: 1.1087 Acc: 0.5480
# val Loss: 1.0859 Acc: 0.6173
#
# Epoch 5/199
# ----------
# train Loss: 1.0673 Acc: 0.5653
# val Loss: 1.1085 Acc: 0.5309
#
# Epoch 6/199
# ----------
# train Loss: 1.0722 Acc: 0.5735
# val Loss: 1.1207 Acc: 0.5309
#
# Epoch 7/199
# ----------
# train Loss: 1.0843 Acc: 0.5588
# val Loss: 1.0415 Acc: 0.5802
#
# Epoch 8/199
# ----------
# train Loss: 1.0644 Acc: 0.5694
# val Loss: 1.1234 Acc: 0.5062
#
# Epoch 9/199
# ----------
# train Loss: 1.0255 Acc: 0.5956
# val Loss: 1.0532 Acc: 0.5926
#
# Epoch 10/199
# ----------
# train Loss: 1.0257 Acc: 0.5951
# val Loss: 0.9135 Acc: 0.6296
#
# Epoch 11/199
# ----------
# train Loss: 0.9932 Acc: 0.6090
# val Loss: 0.9872 Acc: 0.6543
#
# Epoch 12/199
# ----------
# train Loss: 1.0002 Acc: 0.6057
# val Loss: 1.0772 Acc: 0.5926
#
# Epoch 13/199
# ----------
# train Loss: 0.9917 Acc: 0.6129
# val Loss: 0.8239 Acc: 0.6667
#
# Epoch 14/199
# ----------
# train Loss: 0.9710 Acc: 0.6184
# val Loss: 0.8994 Acc: 0.6667
#
# Epoch 15/199
# ----------
# train Loss: 0.9845 Acc: 0.6136
# val Loss: 0.7086 Acc: 0.7778
#
# Epoch 16/199
# ----------
# train Loss: 0.9649 Acc: 0.6189
# val Loss: 0.4311 Acc: 0.8395
#
# Epoch 51/199
# ----------
# train Loss: 0.7041 Acc: 0.7303
# val Loss: 0.3592 Acc: 0.8519
#
# Epoch 52/199
# ----------
# train Loss: 0.7028 Acc: 0.7366
# val Loss: 0.3596 Acc: 0.8889
#
# Epoch 53/199
# ----------
# train Loss: 0.6988 Acc: 0.7317
# val Loss: 0.4496 Acc: 0.8519
#
# Epoch 54/199
# ----------
# train Loss: 0.6757 Acc: 0.7406
# val Loss: 0.4172 Acc: 0.8642
#
# Epoch 55/199
# ----------
# train Loss: 0.6785 Acc: 0.7524
# val Loss: 0.4312 Acc: 0.8519
#
# Epoch 56/199
# ----------
# train Loss: 0.6668 Acc: 0.7517
# val Loss: 0.3519 Acc: 0.8765
#
# Epoch 57/199
# ----------
# train Loss: 0.6821 Acc: 0.7414
# val Loss: 0.4058 Acc: 0.9136
#
# Epoch 58/199
# ----------
# train Loss: 0.6878 Acc: 0.7315
# val Loss: 0.4032 Acc: 0.8765
#
# Epoch 59/199
# ----------
# train Loss: 0.6588 Acc: 0.7447
# val Loss: 0.4531 Acc: 0.8395
#
# Epoch 60/199
# ----------
# train Loss: 0.6683 Acc: 0.7454
# val Loss: 0.3573 Acc: 0.8765
#
# Epoch 61/199
# ----------
# train Loss: 0.6570 Acc: 0.7541
# val Loss: 0.4369 Acc: 0.8272
#
# Epoch 62/199
# ----------
# train Loss: 0.6561 Acc: 0.7519
# val Loss: 0.4397 Acc: 0.8519
#
# Epoch 63/199
# ----------
# train Loss: 0.6656 Acc: 0.7478
# val Loss: 0.3717 Acc: 0.8889
#
# Epoch 64/199
# ----------
# train Loss: 0.6457 Acc: 0.7639
# val Loss: 0.3776 Acc: 0.9012
#
# Epoch 65/199
# ----------
# train Loss: 0.6269 Acc: 0.7608
# val Loss: 0.3997 Acc: 0.8519
#
# Epoch 66/199
# ----------
# train Loss: 0.6416 Acc: 0.7613
# val Loss: 0.2940 Acc: 0.8889
#
# Epoch 67/199
# ----------
# train Loss: 0.6273 Acc: 0.7603
# val Loss: 0.3690 Acc: 0.8519
#
# Epoch 68/199
# ----------
# train Loss: 0.6333 Acc: 0.7620
# val Loss: 0.2658 Acc: 0.8889
#
# Epoch 69/199
# ----------
# train Loss: 0.6264 Acc: 0.7618
# val Loss: 0.3163 Acc: 0.8642
#
# Epoch 70/199
# ----------
# train Loss: 0.6394 Acc: 0.7570
# val Loss: 0.3833 Acc: 0.8519
#
# Epoch 71/199
# ----------
# train Loss: 0.6404 Acc: 0.7594
# val Loss: 0.3796 Acc: 0.8395
#
# Epoch 72/199
# ----------
# train Loss: 0.6254 Acc: 0.7637
# val Loss: 0.3216 Acc: 0.8889
#
# Epoch 73/199
# ----------
# train Loss: 0.6187 Acc: 0.7610
# val Loss: 0.3848 Acc: 0.8642
#
# Epoch 74/199
# ----------
# train Loss: 0.5963 Acc: 0.7695
# val Loss: 0.3653 Acc: 0.8765
#
# Epoch 75/199
# ----------
# train Loss: 0.6040 Acc: 0.7721
#
# Epoch 126/199
# ----------
# train Loss: 0.4619 Acc: 0.8273
# val Loss: 0.2237 Acc: 0.9383
#
# Epoch 127/199
# ----------
# train Loss: 0.4730 Acc: 0.8204
# val Loss: 0.1941 Acc: 0.9383
#
# Epoch 128/199
# ----------
# train Loss: 0.4600 Acc: 0.8295
# val Loss: 0.1795 Acc: 0.9506
#
# Epoch 129/199
# ----------
# train Loss: 0.4777 Acc: 0.8177
# val Loss: 0.1909 Acc: 0.9136
#
# Epoch 130/199
# ----------
# train Loss: 0.4668 Acc: 0.8237
# val Loss: 0.1876 Acc: 0.9259
#
# Epoch 131/199
# ----------
# train Loss: 0.4469 Acc: 0.8336
# val Loss: 0.1928 Acc: 0.9383
#
# Epoch 132/199
# ----------
# train Loss: 0.4775 Acc: 0.8266
# val Loss: 0.2055 Acc: 0.9259
#
# Epoch 133/199
# ----------
# train Loss: 0.4350 Acc: 0.8396
# val Loss: 0.1792 Acc: 0.9136
#
# Epoch 134/199
# ----------
# train Loss: 0.4569 Acc: 0.8288
# val Loss: 0.2020 Acc: 0.9259
#
# Epoch 135/199
# ----------
# train Loss: 0.4686 Acc: 0.8273
# val Loss: 0.1778 Acc: 0.9630
#
# Epoch 136/199
# ----------
# train Loss: 0.4570 Acc: 0.8357
# val Loss: 0.2112 Acc: 0.9136
#
# Epoch 137/199
# ----------
# train Loss: 0.4654 Acc: 0.8220
# val Loss: 0.2613 Acc: 0.9383
#
# Epoch 138/199
# ----------
# train Loss: 0.4550 Acc: 0.8331
# val Loss: 0.2322 Acc: 0.9136
#
# Epoch 139/199
# ----------
# train Loss: 0.4501 Acc: 0.8343
# val Loss: 0.2028 Acc: 0.9383
#
# Epoch 140/199
# ----------
# train Loss: 0.4440 Acc: 0.8403
# val Loss: 0.1818 Acc: 0.9506
#
# Epoch 141/199
# ----------
# train Loss: 0.4442 Acc: 0.8350
# val Loss: 0.1826 Acc: 0.9383
#
# Epoch 142/199
# ----------
# train Loss: 0.4554 Acc: 0.8343
# val Loss: 0.2256 Acc: 0.9259
#
# Epoch 143/199
# ----------
# train Loss: 0.4384 Acc: 0.8343
# val Loss: 0.1810 Acc: 0.9383
#
# Epoch 144/199
# ----------
# train Loss: 0.4159 Acc: 0.8449
# val Loss: 0.1938 Acc: 0.9136
#
# Epoch 145/199
# ----------
# train Loss: 0.4249 Acc: 0.8408
# val Loss: 0.2117 Acc: 0.9259
#
# Epoch 146/199
# ----------
# train Loss: 0.4381 Acc: 0.8386
# val Loss: 0.1716 Acc: 0.9506
#
# Epoch 147/199
# ----------
# train Loss: 0.4282 Acc: 0.8427
# val Loss: 0.1999 Acc: 0.9259
#
# Epoch 148/199
# ----------
# train Loss: 0.4206 Acc: 0.8444
# val Loss: 0.1771 Acc: 0.9506
#
# Epoch 149/199
# ----------
# train Loss: 0.4317 Acc: 0.8456
# val Loss: 0.2066 Acc: 0.9259
#
# Epoch 150/199
# ----------
# train Loss: 0.4164 Acc: 0.8494
# val Loss: 0.2029 Acc: 0.9136
#
# train Loss: 0.3904 Acc: 0.8569
# val Loss: 0.1574 Acc: 0.9630
#
# Epoch 177/199
# ----------
# train Loss: 0.3964 Acc: 0.8501
# val Loss: 0.1570 Acc: 0.9506
#
# Epoch 178/199
# ----------
# train Loss: 0.3733 Acc: 0.8679
# val Loss: 0.1702 Acc: 0.9383
#
# Epoch 179/199
# ----------
# train Loss: 0.3903 Acc: 0.8581
# val Loss: 0.1593 Acc: 0.9383
#
# Epoch 180/199
# ----------
# train Loss: 0.3937 Acc: 0.8578
# val Loss: 0.1729 Acc: 0.9136
#
# Epoch 181/199
# ----------
# train Loss: 0.3969 Acc: 0.8583
# val Loss: 0.1342 Acc: 0.9506
#
# Epoch 182/199
# ----------
# train Loss: 0.3896 Acc: 0.8535
# val Loss: 0.1612 Acc: 0.9259
#
# Epoch 183/199
# ----------
# train Loss: 0.3786 Acc: 0.8590
# val Loss: 0.1757 Acc: 0.9136
#
# Epoch 184/199
# ----------
# train Loss: 0.3763 Acc: 0.8578
# val Loss: 0.1789 Acc: 0.9383
#
# Epoch 185/199
# ----------
# train Loss: 0.4029 Acc: 0.8561
# val Loss: 0.1734 Acc: 0.9506
#
# Epoch 186/199
# ----------
# train Loss: 0.3886 Acc: 0.8559
# val Loss: 0.1397 Acc: 0.9630
#
# Epoch 187/199
# ----------
# train Loss: 0.3645 Acc: 0.8660
# val Loss: 0.1551 Acc: 0.9383
#
# Epoch 188/199
# ----------
# train Loss: 0.3742 Acc: 0.8622
# val Loss: 0.1620 Acc: 0.9259
#
# Epoch 189/199
# ----------
# train Loss: 0.3836 Acc: 0.8593
# val Loss: 0.1699 Acc: 0.9012
#
# Epoch 190/199
# ----------
# train Loss: 0.3863 Acc: 0.8593
# val Loss: 0.1341 Acc: 0.9506
#
# Epoch 191/199
# ----------
# train Loss: 0.3825 Acc: 0.8617
# val Loss: 0.1601 Acc: 0.9259
#
# Epoch 192/199
# ----------
# train Loss: 0.3856 Acc: 0.8650
# val Loss: 0.1687 Acc: 0.9383
#
# Epoch 193/199
# ----------
# train Loss: 0.3635 Acc: 0.8610
# val Loss: 0.1230 Acc: 0.9630
#
# Epoch 194/199
# ----------
# train Loss: 0.3767 Acc: 0.8610
# val Loss: 0.1716 Acc: 0.9506
#
# Epoch 195/199
# ----------
# train Loss: 0.3729 Acc: 0.8679
# val Loss: 0.1583 Acc: 0.9506
#
# Epoch 196/199
# ----------
# train Loss: 0.3601 Acc: 0.8718
# val Loss: 0.1600 Acc: 0.9383
#
# Epoch 197/199
# ----------
# train Loss: 0.3595 Acc: 0.8749
# val Loss: 0.1417 Acc: 0.9753
#
# Epoch 198/199
# ----------
# train Loss: 0.3737 Acc: 0.8655
# val Loss: 0.1413 Acc: 0.9877
#
# Epoch 199/199
# ----------
# train Loss: 0.3613 Acc: 0.8710
# val Loss: 0.1168 Acc: 0.9753
#
# Training complete in 73m 47s
# Best val Acc: 0.987654
# performing predictions...
# saving model to ./models/mobilenet_0.99.pt...
# saving results to ./predictions/mobilenet_0.99_results.npy...
